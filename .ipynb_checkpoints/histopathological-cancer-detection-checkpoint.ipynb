# %%
# !pip install torch-geometric
# !pip install scikit-learn
# !pip install numpy==1.22.0
# Out:
# Collecting torch-geometric
#   Obtaining dependency information for torch-geometric from https://files.pythonhosted.org/packages/65/4e/6f9a75548a93fedcd4514ae2de9bee1e91bade6b73252b4da32f0e42ac52/torch_geometric-2.4.0-py3-none-any.whl.metadata
#   Downloading torch_geometric-2.4.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch-geometric) (4.66.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch-geometric) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch-geometric) (1.11.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch-geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from torch-geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch-geometric) (5.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch-geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch-geometric) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch-geometric) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch-geometric) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch-geometric) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch-geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch-geometric) (3.2.0)
# Downloading torch_geometric-2.4.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.0 MB/s eta 0:00:00
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.4.0
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Collecting numpy==1.22.0
#   Downloading numpy-1.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 65.4 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# chex 0.1.84 requires numpy>=1.24.1, but you have numpy 1.22.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2023.11.0 which is incompatible.
# cuml 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.11.0 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2023.11.0 which is incompatible.
# dask-cuda 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.11.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.11.0 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.11.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# inequality 1.0.1 requires numpy>=1.23, but you have numpy 1.22.0 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# librosa 0.10.1 requires numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3, but you have numpy 1.22.0 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.3 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2023.11.0 which is incompatible.
# raft-dask 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.11.0 which is incompatible.
# spglm 1.1.0 requires numpy>=1.23, but you have numpy 1.22.0 which is incompatible.
# spreg 1.4.2 requires numpy>=1.23, but you have numpy 1.22.0 which is incompatible.
# tensorflowjs 4.13.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# Successfully installed numpy-1.22.0

# %%
import cv2
import os
import numpy as np
import pandas as pd
from glob import glob
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from skimage.io import imread

# Pytorch Libraries
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, BatchNorm
import torch_geometric.transforms as T
import torch_geometric

from torch.optim import lr_scheduler
from torchvision import models, transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import TensorDataset, DataLoader, Dataset

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from sklearn.metrics import classification_report, roc_curve, roc_auc_score, confusion_matrix, precision_recall_curve, auc
# from sklearn.metrics import plot_roc_curve, plot_confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.svm import SVC

sns.set()
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
meta_data = pd.read_csv('/kaggle/input/histopathologic-cancer-detection/train_labels.csv')
meta_data = meta_data.groupby('label', group_keys=False).apply(lambda x: x.sample(2500))
meta_data.reset_index(drop=True, inplace=True)
meta_data.shape
# Out:
# (5000, 2)

# %%
meta_data.head()
# Out:
#                                          id  label
# 0  aed51da11d532f132fa612af81ac7ddc25317a1a      0
# 1  98103a0398e0cd8885f20fa9f5ceab1c005645c1      0
# 2  afa2c80084532263a01ef4fb7874db6f8d05c99d      0
# 3  df604eef05d9ac2b905b6ea1069b0fdef013e9ec      0
# 4  2e04787e202838e945a9215eb479e2c9a0166d64      0

# %%
base_dir = os.path.join('..', 'input/histopathologic-cancer-detection/train')

imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x 
                     for x in glob(os.path.join(base_dir,'*.tif'))}

meta_data['path'] = meta_data['id'].map(imageid_path_dict.get)
meta_data.head()
# Out:
#                                          id  label  \
# 0  aed51da11d532f132fa612af81ac7ddc25317a1a      0
# 1  98103a0398e0cd8885f20fa9f5ceab1c005645c1      0
# 2  afa2c80084532263a01ef4fb7874db6f8d05c99d      0
# 3  df604eef05d9ac2b905b6ea1069b0fdef013e9ec      0
# 4  2e04787e202838e945a9215eb479e2c9a0166d64      0
#
#                                                 path
# 0  ../input/histopathologic-cancer-detection/trai...
# 1  ../input/histopathologic-cancer-detection/trai...
# 2  ../input/histopathologic-cancer-detection/trai...
# 3  ../input/histopathologic-cancer-detection/trai...
# 4  ../input/histopathologic-cancer-detection/trai...

# %%
n_samples = 6
n_classes = len(meta_data['label'].unique())
df = meta_data.sort_values(['label']).groupby('label')
fig, axs = plt.subplots(n_classes, n_samples, figsize = (10, 4))
for ax, (type_, rows) in zip(axs, df):
    ax[0].set_title('Class: '+ str(type_), fontsize=15)
    for sub_ax, (_, subset) in zip(ax, rows.sample(n_samples).iterrows()):
        img = imread(subset['path'])
        sub_ax.imshow(img)
        sub_ax.axis('off')

# %%
data = []
outliers = []
for path in meta_data['path']:
    img = cv2.imread(path)
        
    avgR = np.mean(img[:,:,2])
    avgG = np.mean(img[:,:,1])
    avgB = np.mean(img[:,:,0])
    RGB = np.mean([avgR, avgG, avgB])
    
    data.append([avgR, avgG, avgB, RGB])
    
    if ((RGB <= 45) or (RGB >= 245)) : outliers.append(meta_data.loc[meta_data['path'] == path].index[0])
    
rgb = pd.DataFrame(data, columns=['Red Channel Mean','Green Channel Mean','Blue Channel Mean', 'RGB Mean'])

meta_data = pd.concat([meta_data.reset_index(drop=True), rgb], axis=1)

# %%
g = sns.pairplot(meta_data[['Red Channel Mean', 'Green Channel Mean', 'Blue Channel Mean', 'RGB Mean', 'label']],
             hue='label', plot_kws = {'alpha': 0.3})

g.fig.set_size_inches(12,8)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
len(outliers)
# Out:
# 12

# %%
extremely_low_pxl_img = meta_data[meta_data['RGB Mean'] <= 45]
extremely_high_pxl_img = meta_data[meta_data['RGB Mean'] >= 245]

# %%
n_samples = 5
df = extremely_high_pxl_img.sort_values(['label']).groupby('label')
fig, axs = plt.subplots(2, n_samples, figsize = (10, 4))
for ax, (type_, rows) in zip(axs, df):
    ax[0].set_title('Class: '+ str(type_), fontsize=15)
    for sub_ax, (_, subset) in zip(ax, rows.sample(n_samples, replace = True).iterrows()):
        img = imread(subset['path'])
        sub_ax.imshow(img)
        sub_ax.axis('off')

# %%
n_samples = 5
df = extremely_low_pxl_img.sort_values(['label']).groupby('label')
fig, axs = plt.subplots(2, n_samples, figsize = (10, 4))
for ax, (type_, rows) in zip(axs, df):
    ax[0].set_title('Class: '+ str(type_), fontsize=15)
    for sub_ax, (_, subset) in zip(ax, rows.sample(n_samples, replace = True).iterrows()):
        img = imread(subset['path'])
        sub_ax.imshow(img)
        sub_ax.axis('off')

# %%
meta_data = meta_data.drop(outliers)
meta_data['label'].value_counts()
# Out:
# label
# 1    2500
# 0    2488
# Name: count, dtype: int64

# %%
class CustomDataset(Dataset):
    def __init__(self, data_df, transform=None):
        self.data_df = data_df
        self.transform = transform

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, index):
        img_path = self.data_df.iloc[index]['path']
        label = self.data_df.iloc[index]['label']
        
        # Load image from file
        img = Image.open(img_path).convert('RGB')
        
        if self.transform is not None:
            img = self.transform(img)
        
        return img, label

# Split data into train and test sets
train_df, test_df = train_test_split(meta_data, test_size=0.2, random_state=42)

# %%
# Define the batch size
batch_size = 32

# %%
# Define the data transforms for training and testing datasets
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
    transforms.RandomRotation(degrees=15),
    transforms.RandomHorizontalFlip(),
    transforms.CenterCrop(size=224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.Resize(size=256),
    transforms.CenterCrop(size=224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Load the data
train_dataset = CustomDataset(train_df, transform=train_transforms)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = CustomDataset(test_df, transform=test_transforms)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def evaluate1(model, loader, criterion):
    correct = 0
    total = 0
    total_loss = 0
    
    model.eval()
    with torch.no_grad():
        for data in loader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs.squeeze(), labels.float())
            total_loss += loss.item()
            predicted = torch.round(torch.sigmoid(outputs))
            total += labels.size(0)
            correct += (predicted == labels.unsqueeze(1)).sum().item()

    acc = correct / total
    avg_loss = total_loss / len(loader)
    model.train()
    return acc, avg_loss

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# define hyperparameters
learning_rate = 0.001
num_epochs = 50
roc_aucs = []

# define binary cross entropy loss
criterion = nn.BCEWithLogitsLoss()

# define ResNet50, VGG19, Inception, and DenseNet121 models
models_dict = {'ResNet50': models.resnet50(weights='DEFAULT'),
               'VGG19': models.vgg19(weights='DEFAULT'),
              'VGG16': models.vgg16(weights='DEFAULT'),
              'DenseNet121': models.densenet121(weights='DEFAULT')}

# define empty lists to store accuracy and loss
accs = []
losses = []

# loop over models
for model_name, model in models_dict.items():
    
    print('Training', model_name, 'model')
    
    if (model_name == 'VGG19') | (model_name == 'VGG16'):
        num_features = model.classifier[-1].in_features
        model.classifier[-1] = nn.Linear(num_features, 512)
        model.classifier.add_module('bn1', nn.BatchNorm1d(512))
        model.classifier.add_module('relu1', nn.ReLU(inplace=True))
        model.classifier.add_module('dropout1', nn.Dropout())
        model.classifier.add_module('fc2', nn.Linear(512, 256))
        model.classifier.add_module('bn2', nn.BatchNorm1d(256))
        model.classifier.add_module('relu2', nn.ReLU(inplace=True))
        model.classifier.add_module('dropout2', nn.Dropout())
        model.classifier.add_module('fc3', nn.Linear(256, 1))
    else:
        if model_name == 'DenseNet121':
            num_ftrs = model.classifier.in_features
            model.classifier = nn.Sequential(
                nn.Linear(num_ftrs, 512),
                nn.BatchNorm1d(512),
                nn.ReLU(inplace=True),
                nn.Dropout(),
                nn.Linear(512, 256),
                nn.BatchNorm1d(256),
                nn.ReLU(inplace=True),
                nn.Dropout(),
                nn.Linear(256, 1)
            )
        else:
            num_ftrs = model.fc.in_features
            model.fc = nn.Sequential(
                nn.Linear(num_ftrs, 512),
                nn.BatchNorm1d(512),
                nn.ReLU(inplace=True),
                nn.Dropout(),
                nn.Linear(512, 256),
                nn.BatchNorm1d(256),
                nn.ReLU(inplace=True),
                nn.Dropout(),
                nn.Linear(256, 1)
            )

    model.to(device)
    
    # define optimizer
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)
    
    # define empty lists to store predictions and labels
    y_preds = []
    y_trues = []
    # train the model
    for epoch in range(num_epochs):
        
        running_loss = 0.0
        total = 0
        correct = 0
        
        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            
            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs)
            loss = criterion(outputs, labels.float().unsqueeze(1))
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            # calculate accuracy
            total += labels.size(0)
            predicted = torch.round(torch.sigmoid(outputs))
            correct += (predicted == labels.unsqueeze(1)).sum().item()
            acc = correct / total

            # append accuracy and loss to the lists
            accs.append(acc)
            losses.append(loss.item())

            # append predictions and labels to the lists
            y_preds += predicted.cpu().detach().numpy().tolist()
            y_trues += labels.cpu().detach().numpy().tolist()

        print('Epoch [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
              .format(epoch+1, num_epochs, loss.item(), acc*100))
        
        # calculate validation accuracy and loss
        val_acc, val_loss = evaluate1(model, test_loader, criterion)
        print('Accuracy of the network on the validation set: %d %%' % (100 * val_acc))

        # adjust learning rate based on validation loss
        scheduler.step(val_loss)
        
    torch.save(model.state_dict(), model_name + '.pt')

# Plot AUC ROC Curve
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs = axs.ravel()
for i, (name, model) in enumerate(models_dict.items()):
    model.eval()
    y_score = []
    y_true = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            model = model.to(device)
            outputs = model(inputs)
            outputs = torch.sigmoid(outputs)
            y_score.extend(outputs.cpu().numpy()[:, 0])
            y_true.extend(labels.cpu().numpy())

    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    axs[i].plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
    axs[i].plot([0, 1], [0, 1], 'k--')
    axs[i].set_xlabel('False Positive Rate')
    axs[i].set_ylabel('True Positive Rate')
    axs[i].set_title(name)
    axs[i].legend(loc="lower right")
    plt.tight_layout()
plt.show()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 75.4MB/s]
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:08<00:00, 68.3MB/s]
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:07<00:00, 73.2MB/s]
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 74.6MB/s]
# Training ResNet50 model
# Epoch [1/50], Loss: 0.4220, Accuracy: 77.99%
# Accuracy of the network on the validation set: 56 %
# Epoch [2/50], Loss: 0.5199, Accuracy: 81.78%
# Accuracy of the network on the validation set: 69 %
# Epoch [3/50], Loss: 0.4569, Accuracy: 83.43%
# Accuracy of the network on the validation set: 83 %
# Epoch [4/50], Loss: 0.6695, Accuracy: 84.11%
# Accuracy of the network on the validation set: 82 %
# Epoch [5/50], Loss: 0.4816, Accuracy: 84.74%
# Accuracy of the network on the validation set: 85 %
# Epoch [6/50], Loss: 0.4033, Accuracy: 86.14%
# Accuracy of the network on the validation set: 86 %
# Epoch [7/50], Loss: 0.5581, Accuracy: 86.59%
# Accuracy of the network on the validation set: 85 %
# Epoch [8/50], Loss: 0.7093, Accuracy: 86.44%
# Accuracy of the network on the validation set: 87 %
# Epoch [9/50], Loss: 0.1981, Accuracy: 86.87%
# Accuracy of the network on the validation set: 84 %
# Epoch [10/50], Loss: 0.2856, Accuracy: 88.32%
# Accuracy of the network on the validation set: 82 %
# Epoch [11/50], Loss: 0.2010, Accuracy: 86.97%
# Accuracy of the network on the validation set: 88 %
# Epoch [12/50], Loss: 0.1562, Accuracy: 88.10%
# Accuracy of the network on the validation set: 83 %
# Epoch [13/50], Loss: 0.1220, Accuracy: 89.82%
# Accuracy of the network on the validation set: 88 %
# Epoch [14/50], Loss: 0.2232, Accuracy: 91.33%
# Accuracy of the network on the validation set: 90 %
# Epoch [15/50], Loss: 0.1501, Accuracy: 90.93%
# Accuracy of the network on the validation set: 90 %
# Epoch [16/50], Loss: 0.1450, Accuracy: 91.95%
# Accuracy of the network on the validation set: 89 %
# Epoch [17/50], Loss: 0.1339, Accuracy: 92.38%
# Accuracy of the network on the validation set: 89 %
# Epoch [18/50], Loss: 0.1128, Accuracy: 92.01%
# Accuracy of the network on the validation set: 89 %
# Epoch [19/50], Loss: 0.3941, Accuracy: 92.81%
# Accuracy of the network on the validation set: 88 %
# Epoch [20/50], Loss: 0.1475, Accuracy: 92.68%
# Accuracy of the network on the validation set: 89 %
# Epoch [21/50], Loss: 0.0955, Accuracy: 93.56%
# Accuracy of the network on the validation set: 89 %
# Epoch [22/50], Loss: 0.2595, Accuracy: 92.56%
# Accuracy of the network on the validation set: 89 %
# Epoch [23/50], Loss: 0.4137, Accuracy: 93.33%
# Accuracy of the network on the validation set: 89 %
# Epoch [24/50], Loss: 0.7820, Accuracy: 92.78%
# Accuracy of the network on the validation set: 88 %
# Epoch [25/50], Loss: 0.1605, Accuracy: 92.56%
# Accuracy of the network on the validation set: 89 %
# Epoch [26/50], Loss: 0.0616, Accuracy: 92.61%
# Accuracy of the network on the validation set: 89 %
# Epoch [27/50], Loss: 0.3474, Accuracy: 93.11%
# Accuracy of the network on the validation set: 90 %
# Epoch [28/50], Loss: 0.2061, Accuracy: 92.21%
# Accuracy of the network on the validation set: 89 %
# Epoch [29/50], Loss: 0.1073, Accuracy: 92.83%
# Accuracy of the network on the validation set: 89 %
# Epoch [30/50], Loss: 0.2265, Accuracy: 92.51%
# Accuracy of the network on the validation set: 89 %
# Epoch [31/50], Loss: 0.1432, Accuracy: 92.96%
# Accuracy of the network on the validation set: 89 %
# Epoch [32/50], Loss: 0.1062, Accuracy: 92.91%
# Accuracy of the network on the validation set: 89 %
# Epoch [33/50], Loss: 0.0800, Accuracy: 92.88%
# Accuracy of the network on the validation set: 89 %
# Epoch [34/50], Loss: 0.2253, Accuracy: 93.03%
# Accuracy of the network on the validation set: 89 %
# Epoch [35/50], Loss: 0.1378, Accuracy: 92.91%
# Accuracy of the network on the validation set: 89 %
# Epoch [36/50], Loss: 0.0498, Accuracy: 92.93%
# Accuracy of the network on the validation set: 90 %
# Epoch [37/50], Loss: 0.1372, Accuracy: 93.08%
# Accuracy of the network on the validation set: 89 %
# Epoch [38/50], Loss: 0.1705, Accuracy: 92.93%
# Accuracy of the network on the validation set: 89 %
# Epoch [39/50], Loss: 0.0391, Accuracy: 92.21%
# Accuracy of the network on the validation set: 89 %
# Epoch [40/50], Loss: 0.1292, Accuracy: 93.23%
# Accuracy of the network on the validation set: 89 %
# Epoch [41/50], Loss: 0.1674, Accuracy: 92.98%
# Accuracy of the network on the validation set: 89 %
# Epoch [42/50], Loss: 0.1611, Accuracy: 92.83%
# Accuracy of the network on the validation set: 89 %
# Epoch [43/50], Loss: 0.2081, Accuracy: 92.61%
# Accuracy of the network on the validation set: 89 %
# Epoch [44/50], Loss: 0.2822, Accuracy: 93.16%
# Accuracy of the network on the validation set: 90 %
# Epoch [45/50], Loss: 0.3879, Accuracy: 92.76%
# Accuracy of the network on the validation set: 90 %
# Epoch [46/50], Loss: 0.1058, Accuracy: 92.58%
# Accuracy of the network on the validation set: 89 %
# Epoch [47/50], Loss: 0.1262, Accuracy: 92.81%
# Accuracy of the network on the validation set: 89 %
# Epoch [48/50], Loss: 0.2088, Accuracy: 92.81%
# Accuracy of the network on the validation set: 89 %
# Epoch [49/50], Loss: 0.1448, Accuracy: 92.86%
# Accuracy of the network on the validation set: 89 %
# Epoch [50/50], Loss: 0.0801, Accuracy: 93.03%
# Accuracy of the network on the validation set: 89 %
# Training VGG19 model
# Epoch [1/50], Loss: 0.6107, Accuracy: 74.21%
# Accuracy of the network on the validation set: 68 %
# Epoch [2/50], Loss: 0.4385, Accuracy: 79.80%
# Accuracy of the network on the validation set: 71 %
# Epoch [3/50], Loss: 0.4140, Accuracy: 81.30%
# Accuracy of the network on the validation set: 74 %
# Epoch [4/50], Loss: 0.4603, Accuracy: 82.11%
# Accuracy of the network on the validation set: 81 %
# Epoch [5/50], Loss: 0.5283, Accuracy: 81.73%
# Accuracy of the network on the validation set: 79 %
# Epoch [6/50], Loss: 0.4527, Accuracy: 81.48%
# Accuracy of the network on the validation set: 82 %
# Epoch [7/50], Loss: 0.3614, Accuracy: 81.90%
# Accuracy of the network on the validation set: 80 %
# Epoch [8/50], Loss: 0.6180, Accuracy: 82.48%
# Accuracy of the network on the validation set: 80 %
# Epoch [9/50], Loss: 0.6945, Accuracy: 82.28%
# Accuracy of the network on the validation set: 82 %
# Epoch [10/50], Loss: 0.2801, Accuracy: 83.01%
# Accuracy of the network on the validation set: 78 %
# Epoch [11/50], Loss: 0.3157, Accuracy: 82.23%
# Accuracy of the network on the validation set: 79 %
# Epoch [12/50], Loss: 0.3347, Accuracy: 83.18%
# Accuracy of the network on the validation set: 81 %
# Epoch [13/50], Loss: 0.2877, Accuracy: 83.76%
# Accuracy of the network on the validation set: 83 %
# Epoch [14/50], Loss: 0.4635, Accuracy: 84.01%
# Accuracy of the network on the validation set: 83 %
# Epoch [15/50], Loss: 0.6064, Accuracy: 83.68%
# Accuracy of the network on the validation set: 82 %
# Epoch [16/50], Loss: 0.4477, Accuracy: 84.44%
# Accuracy of the network on the validation set: 83 %
# Epoch [17/50], Loss: 0.3596, Accuracy: 83.98%
# Accuracy of the network on the validation set: 82 %
# Epoch [18/50], Loss: 0.3447, Accuracy: 84.06%
# Accuracy of the network on the validation set: 84 %
# Epoch [19/50], Loss: 0.3358, Accuracy: 84.59%
# Accuracy of the network on the validation set: 84 %
# Epoch [20/50], Loss: 0.4039, Accuracy: 84.64%
# Accuracy of the network on the validation set: 83 %
# Epoch [21/50], Loss: 0.3156, Accuracy: 85.01%
# Accuracy of the network on the validation set: 83 %
# Epoch [22/50], Loss: 0.1217, Accuracy: 84.64%
# Accuracy of the network on the validation set: 84 %
# Epoch [23/50], Loss: 0.4847, Accuracy: 85.09%
# Accuracy of the network on the validation set: 84 %
# Epoch [24/50], Loss: 0.4118, Accuracy: 85.19%
# Accuracy of the network on the validation set: 84 %
# Epoch [25/50], Loss: 0.6924, Accuracy: 85.24%
# Accuracy of the network on the validation set: 84 %
# Epoch [26/50], Loss: 0.3839, Accuracy: 85.24%
# Accuracy of the network on the validation set: 84 %
# Epoch [27/50], Loss: 0.5506, Accuracy: 85.56%
# Accuracy of the network on the validation set: 84 %
# Epoch [28/50], Loss: 0.4164, Accuracy: 85.39%
# Accuracy of the network on the validation set: 84 %
# Epoch [29/50], Loss: 0.3512, Accuracy: 85.36%
# Accuracy of the network on the validation set: 84 %
# Epoch [30/50], Loss: 0.2475, Accuracy: 85.16%
# Accuracy of the network on the validation set: 84 %
# Epoch [31/50], Loss: 0.3150, Accuracy: 85.21%
# Accuracy of the network on the validation set: 84 %
# Epoch [32/50], Loss: 0.4655, Accuracy: 85.29%
# Accuracy of the network on the validation set: 84 %
# Epoch [33/50], Loss: 0.3031, Accuracy: 85.69%
# Accuracy of the network on the validation set: 84 %
# Epoch [34/50], Loss: 0.4247, Accuracy: 85.34%
# Accuracy of the network on the validation set: 84 %
# Epoch [35/50], Loss: 0.4799, Accuracy: 85.24%
# Accuracy of the network on the validation set: 84 %
# Epoch [36/50], Loss: 0.4086, Accuracy: 85.71%
# Accuracy of the network on the validation set: 84 %
# Epoch [37/50], Loss: 0.2190, Accuracy: 85.01%
# Accuracy of the network on the validation set: 84 %
# Epoch [38/50], Loss: 0.3070, Accuracy: 84.71%
# Accuracy of the network on the validation set: 84 %
# Epoch [39/50], Loss: 0.2905, Accuracy: 85.56%
# Accuracy of the network on the validation set: 84 %
# Epoch [40/50], Loss: 0.1934, Accuracy: 85.81%
# Accuracy of the network on the validation set: 84 %
# Epoch [41/50], Loss: 0.2739, Accuracy: 85.31%
# Accuracy of the network on the validation set: 84 %
# Epoch [42/50], Loss: 0.2321, Accuracy: 85.41%
# Accuracy of the network on the validation set: 84 %
# Epoch [43/50], Loss: 0.3125, Accuracy: 85.56%
# Accuracy of the network on the validation set: 84 %
# Epoch [44/50], Loss: 0.6280, Accuracy: 84.79%
# Accuracy of the network on the validation set: 84 %
# Epoch [45/50], Loss: 0.5561, Accuracy: 84.74%
# Accuracy of the network on the validation set: 84 %
# Epoch [46/50], Loss: 0.1795, Accuracy: 85.84%
# Accuracy of the network on the validation set: 84 %
# Epoch [47/50], Loss: 0.2879, Accuracy: 84.54%
# Accuracy of the network on the validation set: 84 %
# Epoch [48/50], Loss: 0.6411, Accuracy: 85.16%
# Accuracy of the network on the validation set: 84 %
# Epoch [49/50], Loss: 0.1411, Accuracy: 85.56%
# Accuracy of the network on the validation set: 84 %
# Epoch [50/50], Loss: 0.1483, Accuracy: 85.16%
# Accuracy of the network on the validation set: 84 %
# Training VGG16 model
# Epoch [1/50], Loss: 0.4682, Accuracy: 76.02%
# Accuracy of the network on the validation set: 67 %
# Epoch [2/50], Loss: 0.4367, Accuracy: 79.77%
# Accuracy of the network on the validation set: 80 %
# Epoch [3/50], Loss: 0.2204, Accuracy: 81.50%
# Accuracy of the network on the validation set: 81 %
# Epoch [4/50], Loss: 0.6818, Accuracy: 81.35%
# Accuracy of the network on the validation set: 71 %
# Epoch [5/50], Loss: 0.6138, Accuracy: 81.10%
# Accuracy of the network on the validation set: 81 %
# Epoch [6/50], Loss: 0.3226, Accuracy: 81.83%
# Accuracy of the network on the validation set: 81 %
# Epoch [7/50], Loss: 0.4392, Accuracy: 82.13%
# Accuracy of the network on the validation set: 80 %
# Epoch [8/50], Loss: 0.6182, Accuracy: 82.36%
# Accuracy of the network on the validation set: 76 %
# Epoch [9/50], Loss: 0.2542, Accuracy: 82.41%
# Accuracy of the network on the validation set: 81 %
# Epoch [10/50], Loss: 0.5111, Accuracy: 82.31%
# Accuracy of the network on the validation set: 63 %
# Epoch [11/50], Loss: 0.5146, Accuracy: 82.21%
# Accuracy of the network on the validation set: 82 %
# Epoch [12/50], Loss: 0.3660, Accuracy: 82.51%
# Accuracy of the network on the validation set: 80 %
# Epoch [13/50], Loss: 0.3458, Accuracy: 81.88%
# Accuracy of the network on the validation set: 83 %
# Epoch [14/50], Loss: 0.4127, Accuracy: 82.83%
# Accuracy of the network on the validation set: 83 %
# Epoch [15/50], Loss: 0.4063, Accuracy: 83.13%
# Accuracy of the network on the validation set: 76 %
# Epoch [16/50], Loss: 0.2464, Accuracy: 83.21%
# Accuracy of the network on the validation set: 71 %
# Epoch [17/50], Loss: 0.2678, Accuracy: 83.08%
# Accuracy of the network on the validation set: 82 %
# Epoch [18/50], Loss: 0.2894, Accuracy: 83.11%
# Accuracy of the network on the validation set: 80 %
# Epoch [19/50], Loss: 0.3142, Accuracy: 84.56%
# Accuracy of the network on the validation set: 83 %
# Epoch [20/50], Loss: 0.4356, Accuracy: 85.34%
# Accuracy of the network on the validation set: 84 %
# Epoch [21/50], Loss: 0.2562, Accuracy: 85.29%
# Accuracy of the network on the validation set: 84 %
# Epoch [22/50], Loss: 0.4322, Accuracy: 84.69%
# Accuracy of the network on the validation set: 84 %
# Epoch [23/50], Loss: 0.4329, Accuracy: 85.21%
# Accuracy of the network on the validation set: 84 %
# Epoch [24/50], Loss: 0.3793, Accuracy: 84.99%
# Accuracy of the network on the validation set: 82 %
# Epoch [25/50], Loss: 0.3142, Accuracy: 85.26%
# Accuracy of the network on the validation set: 84 %
# Epoch [26/50], Loss: 0.4303, Accuracy: 85.69%
# Accuracy of the network on the validation set: 85 %
# Epoch [27/50], Loss: 0.1917, Accuracy: 85.69%
# Accuracy of the network on the validation set: 83 %
# Epoch [28/50], Loss: 0.3826, Accuracy: 85.81%
# Accuracy of the network on the validation set: 84 %
# Epoch [29/50], Loss: 0.5028, Accuracy: 86.17%
# Accuracy of the network on the validation set: 85 %
# Epoch [30/50], Loss: 0.4354, Accuracy: 85.79%
# Accuracy of the network on the validation set: 85 %
# Epoch [31/50], Loss: 0.2713, Accuracy: 85.96%
# Accuracy of the network on the validation set: 83 %
# Epoch [32/50], Loss: 0.3446, Accuracy: 86.09%
# Accuracy of the network on the validation set: 84 %
# Epoch [33/50], Loss: 0.1634, Accuracy: 86.57%
# Accuracy of the network on the validation set: 85 %
# Epoch [34/50], Loss: 0.5028, Accuracy: 86.52%
# Accuracy of the network on the validation set: 85 %
# Epoch [35/50], Loss: 0.3335, Accuracy: 86.44%
# Accuracy of the network on the validation set: 84 %
# Epoch [36/50], Loss: 0.6961, Accuracy: 87.12%
# Accuracy of the network on the validation set: 85 %
# Epoch [37/50], Loss: 0.1880, Accuracy: 86.57%
# Accuracy of the network on the validation set: 85 %
# Epoch [38/50], Loss: 0.6145, Accuracy: 86.32%
# Accuracy of the network on the validation set: 85 %
# Epoch [39/50], Loss: 0.3283, Accuracy: 87.57%
# Accuracy of the network on the validation set: 85 %
# Epoch [40/50], Loss: 0.2928, Accuracy: 87.04%
# Accuracy of the network on the validation set: 84 %
# Epoch [41/50], Loss: 0.2542, Accuracy: 87.57%
# Accuracy of the network on the validation set: 85 %
# Epoch [42/50], Loss: 0.3317, Accuracy: 87.32%
# Accuracy of the network on the validation set: 85 %
# Epoch [43/50], Loss: 0.3821, Accuracy: 87.24%
# Accuracy of the network on the validation set: 85 %
# Epoch [44/50], Loss: 0.2051, Accuracy: 86.97%
# Accuracy of the network on the validation set: 85 %
# Epoch [45/50], Loss: 0.2559, Accuracy: 86.99%
# Accuracy of the network on the validation set: 85 %
# Epoch [46/50], Loss: 0.3181, Accuracy: 87.07%
# Accuracy of the network on the validation set: 85 %
# Epoch [47/50], Loss: 0.2725, Accuracy: 87.72%
# Accuracy of the network on the validation set: 85 %
# Epoch [48/50], Loss: 0.2324, Accuracy: 87.29%
# Accuracy of the network on the validation set: 85 %
# Epoch [49/50], Loss: 0.3579, Accuracy: 87.19%
# Accuracy of the network on the validation set: 85 %
# Epoch [50/50], Loss: 0.3283, Accuracy: 87.84%
# Accuracy of the network on the validation set: 85 %
# Training DenseNet121 model
# Epoch [1/50], Loss: 0.3263, Accuracy: 78.02%
# Accuracy of the network on the validation set: 79 %
# Epoch [2/50], Loss: 0.3590, Accuracy: 82.28%
# Accuracy of the network on the validation set: 80 %
# Epoch [3/50], Loss: 0.2897, Accuracy: 82.76%
# Accuracy of the network on the validation set: 85 %
# Epoch [4/50], Loss: 0.4015, Accuracy: 84.36%
# Accuracy of the network on the validation set: 84 %
# Epoch [5/50], Loss: 0.2001, Accuracy: 85.84%
# Accuracy of the network on the validation set: 84 %
# Epoch [6/50], Loss: 0.5099, Accuracy: 86.34%
# Accuracy of the network on the validation set: 82 %
# Epoch [7/50], Loss: 0.3460, Accuracy: 86.94%
# Accuracy of the network on the validation set: 87 %
# Epoch [8/50], Loss: 0.5925, Accuracy: 87.52%
# Accuracy of the network on the validation set: 89 %
# Epoch [9/50], Loss: 0.5000, Accuracy: 87.32%
# Accuracy of the network on the validation set: 88 %
# Epoch [10/50], Loss: 0.4450, Accuracy: 88.60%
# Accuracy of the network on the validation set: 83 %
# Epoch [11/50], Loss: 0.5979, Accuracy: 87.92%
# Accuracy of the network on the validation set: 88 %
# Epoch [12/50], Loss: 0.0771, Accuracy: 89.02%
# Accuracy of the network on the validation set: 87 %
# Epoch [13/50], Loss: 0.1820, Accuracy: 90.73%
# Accuracy of the network on the validation set: 91 %
# Epoch [14/50], Loss: 0.2401, Accuracy: 92.06%
# Accuracy of the network on the validation set: 90 %
# Epoch [15/50], Loss: 0.4435, Accuracy: 92.66%
# Accuracy of the network on the validation set: 90 %
# Epoch [16/50], Loss: 0.1674, Accuracy: 92.46%
# Accuracy of the network on the validation set: 90 %
# Epoch [17/50], Loss: 0.3230, Accuracy: 92.41%
# Accuracy of the network on the validation set: 89 %
# Epoch [18/50], Loss: 0.1168, Accuracy: 92.53%
# Accuracy of the network on the validation set: 90 %
# Epoch [19/50], Loss: 0.3473, Accuracy: 92.56%
# Accuracy of the network on the validation set: 90 %
# Epoch [20/50], Loss: 0.3056, Accuracy: 92.31%
# Accuracy of the network on the validation set: 91 %
# Epoch [21/50], Loss: 0.3064, Accuracy: 93.01%
# Accuracy of the network on the validation set: 91 %
# Epoch [22/50], Loss: 0.0732, Accuracy: 93.46%
# Accuracy of the network on the validation set: 90 %
# Epoch [23/50], Loss: 0.0477, Accuracy: 93.66%
# Accuracy of the network on the validation set: 90 %
# Epoch [24/50], Loss: 0.1890, Accuracy: 93.68%
# Accuracy of the network on the validation set: 91 %
# Epoch [25/50], Loss: 0.4759, Accuracy: 93.26%
# Accuracy of the network on the validation set: 91 %
# Epoch [26/50], Loss: 0.2095, Accuracy: 93.83%
# Accuracy of the network on the validation set: 91 %
# Epoch [27/50], Loss: 0.1372, Accuracy: 94.21%
# Accuracy of the network on the validation set: 90 %
# Epoch [28/50], Loss: 0.2290, Accuracy: 93.76%
# Accuracy of the network on the validation set: 91 %
# Epoch [29/50], Loss: 0.0671, Accuracy: 93.58%
# Accuracy of the network on the validation set: 90 %
# Epoch [30/50], Loss: 0.0242, Accuracy: 93.48%
# Accuracy of the network on the validation set: 91 %
# Epoch [31/50], Loss: 0.1623, Accuracy: 94.16%
# Accuracy of the network on the validation set: 91 %
# Epoch [32/50], Loss: 0.3092, Accuracy: 94.19%
# Accuracy of the network on the validation set: 91 %
# Epoch [33/50], Loss: 0.2376, Accuracy: 93.11%
# Accuracy of the network on the validation set: 90 %
# Epoch [34/50], Loss: 0.1522, Accuracy: 93.91%
# Accuracy of the network on the validation set: 91 %
# Epoch [35/50], Loss: 0.1995, Accuracy: 93.93%
# Accuracy of the network on the validation set: 91 %
# Epoch [36/50], Loss: 0.0701, Accuracy: 93.38%
# Accuracy of the network on the validation set: 90 %
# Epoch [37/50], Loss: 0.0449, Accuracy: 93.28%
# Accuracy of the network on the validation set: 90 %
# Epoch [38/50], Loss: 0.2513, Accuracy: 93.83%
# Accuracy of the network on the validation set: 91 %
# Epoch [39/50], Loss: 0.1131, Accuracy: 94.11%
# Accuracy of the network on the validation set: 90 %
# Epoch [40/50], Loss: 0.5781, Accuracy: 93.48%
# Accuracy of the network on the validation set: 91 %
# Epoch [41/50], Loss: 0.1276, Accuracy: 94.34%
# Accuracy of the network on the validation set: 91 %
# Epoch [42/50], Loss: 0.1936, Accuracy: 94.34%
# Accuracy of the network on the validation set: 91 %
# Epoch [43/50], Loss: 0.2789, Accuracy: 94.46%
# Accuracy of the network on the validation set: 91 %
# Epoch [44/50], Loss: 0.2384, Accuracy: 94.31%
# Accuracy of the network on the validation set: 91 %
# Epoch [45/50], Loss: 0.2452, Accuracy: 94.41%
# Accuracy of the network on the validation set: 91 %
# Epoch [46/50], Loss: 0.0865, Accuracy: 94.06%
# Accuracy of the network on the validation set: 91 %
# Epoch [47/50], Loss: 0.3397, Accuracy: 94.11%
# Accuracy of the network on the validation set: 91 %
# Epoch [48/50], Loss: 0.3325, Accuracy: 94.21%
# Accuracy of the network on the validation set: 91 %
# Epoch [49/50], Loss: 0.0443, Accuracy: 93.71%
# Accuracy of the network on the validation set: 90 %
# Epoch [50/50], Loss: 0.1372, Accuracy: 94.09%
# Accuracy of the network on the validation set: 91 %

# %%
# Plot Confusion Matrix
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs = axs.ravel()

# Loop through each model and plot its confusion matrix in a subplot
for i, (name, model) in enumerate(models_dict.items()):
    model.eval()
    y_pred = []
    y_true = []
    threshold = 0.5
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            model = model.to(device)
            outputs = model(inputs)
            outputs = torch.sigmoid(outputs)
            output_numpy = outputs.cpu().numpy()
            lab = (output_numpy >= threshold).astype(int)
            y_pred.extend(lab.tolist())
            y_true.extend(labels.cpu().numpy())
            
    y_pred = list(np.array(y_pred).flat)
    ax = axs[i]
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, cmap="Blues", ax=ax, fmt="g")
    ax.set_title("Confusion Matrix - {}".format(name))
    ax.set_xlabel("Predicted Labels")
    ax.set_ylabel("True Labels")

# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.3, wspace=0.3)

# Show the plot
plt.show()

# %%
def evaluate(model, loader, criterion):
    correct = 0
    total = 0
    total_loss = 0
    
    model.eval()
    with torch.no_grad():
        for data in loader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs.squeeze(), labels.float())
            total_loss += loss.item()
            predicted = torch.round(outputs) # round the outputs to 0 or 1
            total += labels.size(0)
            correct += (predicted == labels.unsqueeze(1)).sum().item()

    acc = correct / total
    avg_loss = total_loss / len(loader)
    model.train()
    return acc, avg_loss

# %%
class Ensemble(nn.Module):
    def __init__(self, models_dict):
        super(Ensemble, self).__init__()
        self.models_dict = models_dict
        
    def forward(self, x):
        count = 0
        predicted = 0
        for model_name, model in self.models_dict.items():
            if model_name == 'VGG19':
                count += 0.225*torch.sigmoid(model(x))
            if model_name == 'VGG16':
                count += 0.225*torch.sigmoid(model(x))
            if model_name == 'ResNet50':
                count += 0.275*torch.sigmoid(model(x))
            if model_name == 'DenseNet121':
                count += 0.275*torch.sigmoid(model(x))

        return torch.tensor(count, dtype=torch.float32)
        
    
ensemble = Ensemble(models_dict)

ensemble.to(device)

val_acc, val_loss = evaluate(ensemble, test_loader, criterion)
print('Accuracy of the ensemble on the validation set: %d %%' % (100 * val_acc))
# Out:
# /tmp/ipykernel_26/4123842524.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(count, dtype=torch.float32)
# Accuracy of the ensemble on the validation set: 90 %

# %%
# Evaluate the model on the test set
y_test_preds = []
y_test_trues = []
predlist = []

ensemble.eval()

with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = ensemble(images)
        predicted = torch.round(outputs)
        predlist += predicted.cpu().detach().numpy().tolist()
        outputs = torch.sigmoid(outputs)
        y_test_preds += outputs.cpu().detach().numpy().tolist()
        y_test_trues += labels.cpu().detach().numpy().tolist()

       

# Calculate AUC ROC score
auc_roc_score = roc_auc_score(y_test_trues, y_test_preds)

# Plot ROC curve
fpr, tpr, _ = roc_curve(y_test_trues, y_test_preds)

plt.plot(fpr, tpr, label=f'ROC curve (AUC =%.2f)' % auc_roc_score)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Calculate confusion matrix
confusion_mat = confusion_matrix(y_test_trues, predlist)

# Plot confusion matrix
labels = ['Negative', 'Positive']
plt.figure(figsize=(5,5))
sns.heatmap(confusion_mat, xticklabels=labels, yticklabels=labels, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# /tmp/ipykernel_26/4123842524.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(count, dtype=torch.float32)

# %%
class BinaryCNN(nn.Module):
    def __init__(self):
        super(BinaryCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(256)
        self.fc1 = nn.Linear(256 * 6 * 6, 512)
        self.bn5 = nn.BatchNorm1d(512)
        self.dropout = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(512, 1)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        x = self.pool(nn.functional.relu(self.bn1(self.conv1(x))))
        x = self.pool(nn.functional.relu(self.bn2(self.conv2(x))))
        x = self.pool(nn.functional.relu(self.bn3(self.conv3(x))))
        x = self.pool(nn.functional.relu(self.bn4(self.conv4(x))))
        x = x.view(-1, 256 * 6 * 6)
        x = nn.functional.relu(self.bn5(self.fc1(x)))
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return x

# %%
# Set the hyperparameters
batch_size = 32

train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(size=256),
    transforms.RandomRotation(degrees=15),
    transforms.RandomHorizontalFlip(),
    transforms.CenterCrop(size=96),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.Resize(size=256),
    transforms.CenterCrop(size=96),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])


# Create the datasets and data loaders
dataset_train = CustomDataset(train_df, transform=train_transforms)
dataset_valid = CustomDataset(test_df, transform=test_transforms)
loader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
loader_valid = DataLoader(dataset_valid, batch_size=batch_size)

# %%
learning_rate = 0.005

# Initialize the model, criterion, and optimizer
model = BinaryCNN()
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)

# %%
# Train the model
accs = []
losses = []
y_preds = []
y_trues = []
count = 0
num_epochs = 50

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

for epoch in range(num_epochs):
    running_loss = 0.0
    total = 0
    correct = 0
    for i, data in enumerate(loader_train, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        
        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), labels.float())
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if i % 100 == 99:
            print('[%d, %5d] loss: %.3f' % (epoch + 1, i + 1, running_loss / 100))
            running_loss = 0.0
                
        # calculate accuracy
        total += labels.size(0)
        predicted = torch.round(outputs)
        correct += (predicted == labels.unsqueeze(1)).sum().item()
        acc = correct / total

        # append accuracy and loss to the lists
        accs.append(acc)
        losses.append(loss.item())

        # append predictions and labels to the lists
        y_preds += predicted.cpu().detach().numpy().tolist()
        y_trues += labels.cpu().detach().numpy().tolist()
        
    print('Epoch [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
              .format(epoch+1, num_epochs, loss.item(), acc*100))
    
    # calculate validation accuracy and loss
    val_acc, val_loss = evaluate(model, loader_valid, criterion)
    print('Accuracy of the network on the validation set: %d %%' % (100 * val_acc))
    
    # adjust learning rate based on validation loss
    scheduler.step(val_loss)
# Out:
# [1,   100] loss: 0.618
# Epoch [1/50], Loss: 0.5795, Accuracy: 70.35%
# Accuracy of the network on the validation set: 76 %
# [2,   100] loss: 0.572
# Epoch [2/50], Loss: 0.4451, Accuracy: 72.48%
# Accuracy of the network on the validation set: 67 %
# [3,   100] loss: 0.569
# Epoch [3/50], Loss: 0.5296, Accuracy: 72.76%
# Accuracy of the network on the validation set: 72 %
# [4,   100] loss: 0.555
# Epoch [4/50], Loss: 0.4691, Accuracy: 72.98%
# Accuracy of the network on the validation set: 73 %
# [5,   100] loss: 0.548
# Epoch [5/50], Loss: 0.6757, Accuracy: 73.66%
# Accuracy of the network on the validation set: 75 %
# [6,   100] loss: 0.551
# Epoch [6/50], Loss: 0.5350, Accuracy: 72.91%
# Accuracy of the network on the validation set: 70 %
# [7,   100] loss: 0.540
# Epoch [7/50], Loss: 0.5950, Accuracy: 74.54%
# Accuracy of the network on the validation set: 76 %
# [8,   100] loss: 0.537
# Epoch [8/50], Loss: 0.5798, Accuracy: 74.71%
# Accuracy of the network on the validation set: 76 %
# [9,   100] loss: 0.520
# Epoch [9/50], Loss: 0.7831, Accuracy: 75.26%
# Accuracy of the network on the validation set: 77 %
# [10,   100] loss: 0.514
# Epoch [10/50], Loss: 0.6262, Accuracy: 75.14%
# Accuracy of the network on the validation set: 75 %
# [11,   100] loss: 0.524
# Epoch [11/50], Loss: 0.4772, Accuracy: 75.09%
# Accuracy of the network on the validation set: 69 %
# [12,   100] loss: 0.527
# Epoch [12/50], Loss: 0.4875, Accuracy: 74.34%
# Accuracy of the network on the validation set: 78 %
# [13,   100] loss: 0.518
# Epoch [13/50], Loss: 0.6158, Accuracy: 75.69%
# Accuracy of the network on the validation set: 77 %
# [14,   100] loss: 0.517
# Epoch [14/50], Loss: 0.4056, Accuracy: 75.29%
# Accuracy of the network on the validation set: 75 %
# [15,   100] loss: 0.515
# Epoch [15/50], Loss: 0.6967, Accuracy: 74.99%
# Accuracy of the network on the validation set: 76 %
# [16,   100] loss: 0.512
# Epoch [16/50], Loss: 0.3491, Accuracy: 76.17%
# Accuracy of the network on the validation set: 75 %
# [17,   100] loss: 0.512
# Epoch [17/50], Loss: 0.4843, Accuracy: 75.74%
# Accuracy of the network on the validation set: 78 %
# [18,   100] loss: 0.496
# Epoch [18/50], Loss: 0.5932, Accuracy: 76.74%
# Accuracy of the network on the validation set: 76 %
# [19,   100] loss: 0.508
# Epoch [19/50], Loss: 0.4402, Accuracy: 76.77%
# Accuracy of the network on the validation set: 76 %
# [20,   100] loss: 0.509
# Epoch [20/50], Loss: 0.4530, Accuracy: 75.74%
# Accuracy of the network on the validation set: 78 %
# [21,   100] loss: 0.506
# Epoch [21/50], Loss: 0.4810, Accuracy: 77.37%
# Accuracy of the network on the validation set: 77 %
# [22,   100] loss: 0.489
# Epoch [22/50], Loss: 0.8279, Accuracy: 77.44%
# Accuracy of the network on the validation set: 79 %
# [23,   100] loss: 0.488
# Epoch [23/50], Loss: 0.5131, Accuracy: 77.84%
# Accuracy of the network on the validation set: 78 %
# [24,   100] loss: 0.481
# Epoch [24/50], Loss: 0.3415, Accuracy: 76.82%
# Accuracy of the network on the validation set: 78 %
# [25,   100] loss: 0.477
# Epoch [25/50], Loss: 0.4522, Accuracy: 77.79%
# Accuracy of the network on the validation set: 79 %
# [26,   100] loss: 0.477
# Epoch [26/50], Loss: 0.7478, Accuracy: 76.77%
# Accuracy of the network on the validation set: 80 %
# [27,   100] loss: 0.492
# Epoch [27/50], Loss: 0.5123, Accuracy: 76.79%
# Accuracy of the network on the validation set: 80 %
# [28,   100] loss: 0.497
# Epoch [28/50], Loss: 0.5763, Accuracy: 76.69%
# Accuracy of the network on the validation set: 79 %
# [29,   100] loss: 0.487
# Epoch [29/50], Loss: 0.4023, Accuracy: 76.64%
# Accuracy of the network on the validation set: 80 %
# [30,   100] loss: 0.478
# Epoch [30/50], Loss: 0.5309, Accuracy: 77.22%
# Accuracy of the network on the validation set: 79 %
# [31,   100] loss: 0.485
# Epoch [31/50], Loss: 0.3983, Accuracy: 77.22%
# Accuracy of the network on the validation set: 79 %
# [32,   100] loss: 0.478
# Epoch [32/50], Loss: 0.3348, Accuracy: 77.09%
# Accuracy of the network on the validation set: 79 %
# [33,   100] loss: 0.485
# Epoch [33/50], Loss: 0.3972, Accuracy: 77.62%
# Accuracy of the network on the validation set: 79 %
# [34,   100] loss: 0.478
# Epoch [34/50], Loss: 0.5368, Accuracy: 77.77%
# Accuracy of the network on the validation set: 79 %
# [35,   100] loss: 0.488
# Epoch [35/50], Loss: 0.5718, Accuracy: 77.34%
# Accuracy of the network on the validation set: 79 %
# [36,   100] loss: 0.479
# Epoch [36/50], Loss: 0.4157, Accuracy: 77.52%
# Accuracy of the network on the validation set: 79 %
# [37,   100] loss: 0.489
# Epoch [37/50], Loss: 0.3855, Accuracy: 77.94%
# Accuracy of the network on the validation set: 80 %
# [38,   100] loss: 0.479
# Epoch [38/50], Loss: 0.4275, Accuracy: 76.99%
# Accuracy of the network on the validation set: 80 %
# [39,   100] loss: 0.473
# Epoch [39/50], Loss: 0.4611, Accuracy: 77.82%
# Accuracy of the network on the validation set: 80 %
# [40,   100] loss: 0.492
# Epoch [40/50], Loss: 0.3777, Accuracy: 77.32%
# Accuracy of the network on the validation set: 80 %
# [41,   100] loss: 0.489
# Epoch [41/50], Loss: 0.4557, Accuracy: 77.82%
# Accuracy of the network on the validation set: 79 %
# [42,   100] loss: 0.475
# Epoch [42/50], Loss: 0.4397, Accuracy: 77.47%
# Accuracy of the network on the validation set: 79 %
# [43,   100] loss: 0.478
# Epoch [43/50], Loss: 0.6378, Accuracy: 77.97%
# Accuracy of the network on the validation set: 79 %
# [44,   100] loss: 0.486
# Epoch [44/50], Loss: 0.5689, Accuracy: 77.19%
# Accuracy of the network on the validation set: 79 %
# [45,   100] loss: 0.482
# Epoch [45/50], Loss: 0.5094, Accuracy: 78.17%
# Accuracy of the network on the validation set: 79 %
# [46,   100] loss: 0.464
# Epoch [46/50], Loss: 0.3293, Accuracy: 78.32%
# Accuracy of the network on the validation set: 79 %
# [47,   100] loss: 0.470
# Epoch [47/50], Loss: 0.4007, Accuracy: 77.84%
# Accuracy of the network on the validation set: 80 %
# [48,   100] loss: 0.473
# Epoch [48/50], Loss: 0.3632, Accuracy: 78.47%
# Accuracy of the network on the validation set: 79 %
# [49,   100] loss: 0.476
# Epoch [49/50], Loss: 0.7340, Accuracy: 77.42%
# Accuracy of the network on the validation set: 79 %
# [50,   100] loss: 0.481
# Epoch [50/50], Loss: 0.7320, Accuracy: 77.34%
# Accuracy of the network on the validation set: 80 %

# %%
# Evaluate the model on the test set
y_test_preds = []
y_test_trues = []
predlist = []

model.eval()

with torch.no_grad():
    for data in loader_valid:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        predicted = torch.round(outputs)
        predlist += predicted.cpu().detach().numpy().tolist()
        outputs = torch.sigmoid(outputs)
        y_test_preds += outputs.cpu().detach().numpy().tolist()
        y_test_trues += labels.cpu().detach().numpy().tolist()

# Calculate AUC ROC score
auc_roc_score = roc_auc_score(y_test_trues, y_test_preds)

# Plot ROC curve
fpr, tpr, _ = roc_curve(y_test_trues, y_test_preds)

plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % auc_roc_score)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Calculate confusion matrix
confusion_mat = confusion_matrix(y_test_trues, predlist)

# Plot confusion matrix
labels = ['Negative', 'Positive']
plt.figure(figsize=(5,5))
sns.heatmap(confusion_mat, xticklabels=labels, yticklabels=labels, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
